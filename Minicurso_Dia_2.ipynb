# %% [markdown]
# # Pandas
# * Pandas is a Python library used for working with data sets.
# * It has functions for analyzing, cleaning, exploring, and manipulating big amounts of data.
#  * Is there a correlation between two or more columns?
#  * What is average value?
#  * Max value?
#  * Min value?
#
# **DataFrame**
#
# * A data frame is a structured representation of data.

# %%
import pandas as pd

mydataset = {
  'student': ["Derick", "Jena", "Ford"],
  'grades': [3, 7, 2]
}

df = pd.DataFrame(data=mydataset, index = [0,1,2])

df['class'] = ['Math', 'IA', 'Databases']

print(df.shape,'\n')
print(df,'\n')
print(df.loc[0],'\n') #row 0
print(df['student'])
# Out:
# (3, 3)
#
#   student  grades      class
# 0  Derick       3       Math
# 1    Jena       7         IA
# 2    Ford       2  Databases
#
# student    Derick
# grades          3
# class        Math
# Name: 0, dtype: object
#
# 0    Derick
# 1      Jena
# 2      Ford
# Name: student, dtype: object

# %%
df
# Out:
#   student  grades      class
# 0  Derick       3       Math
# 1    Jena       7         IA
# 2    Ford       2  Databases

# %% [markdown]
# # Estudo de Caso
# **Bitcoin**<br>
# ![bitcoins2-768x502-737577519.png](data:image/png;base64,...)

# %% [markdown]
# ![Bitcoin-Explained-in-30-Seconds2.webp](data:image/webp;base64,...)

# %% [markdown]
# **Cotações**
# * https://finance.yahoo.com/quote/BTC-USD?p=BTC-USD<br>
# * https://www.tradingview.com/symbols/BTCUSD/<br>
#
# **CSV [01-01-2015 to 01-10-2022]** <br>
# Download https://drive.google.com/file/d/1gOJj5OEQgcdYJowdUw7rNZg31TkkO0Xp/view?usp=sharing

# %% [markdown]
# # Análise Exploratória de Dados

# %%
import pandas as pd
df = pd.read_csv("BTC-USD.csv", header=0, sep=",")
df
# Out:
#             Date          Open          High           Low         Close  \
# 0     2015-01-01    320.434998    320.434998    314.002991    314.248993
# 1     2015-01-02    314.079010    315.838989    313.565002    315.032013
# 2     2015-01-03    314.846008    315.149994    281.082001    281.082001
# 3     2015-01-04    281.145996    287.230011    257.612000    264.195007
# 4     2015-01-05    265.084015    278.341003    265.084015    274.473999
# ...          ...           ...           ...           ...           ...
# 2826  2022-09-27  19221.839844  20338.455078  18915.667969  19110.546875
# 2827  2022-09-28  19104.621094  19688.343750  18553.296875  19426.720703
# 2828  2022-09-29  19427.779297  19589.265625  18924.353516  19573.050781
# 2829  2022-09-30  19573.431641  20109.849609  19265.662109  19431.789063
# 2830  2022-10-01  19431.105469  19471.154297  19231.082031  19312.095703
#
#          Adj Close       Volume
# 0       314.248993      8036550
# 1       315.032013      7860650
# 2       281.082001     33054400
# 3       264.195007     55629100
# 4       274.473999     43962800
# ...            ...          ...
# 2826  19110.546875  58571439619
# 2827  19426.720703  53071298734
# 2828  19573.050781  41037843771
# 2829  19431.789063  43975248085
# 2830  19312.095703  18719537670
#
# [2831 rows x 7 columns]

# %%
df.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2015-01-01  320.434998  320.434998  314.002991  314.248993  314.248993
# 1  2015-01-02  314.079010  315.838989  313.565002  315.032013  315.032013
# 2  2015-01-03  314.846008  315.149994  281.082001  281.082001  281.082001
# 3  2015-01-04  281.145996  287.230011  257.612000  264.195007  264.195007
# 4  2015-01-05  265.084015  278.341003  265.084015  274.473999  274.473999
#
#      Volume
# 0   8036550
# 1   7860650
# 2  33054400
# 3  55629100
# 4  43962800

# %%
df.tail(6)
# Out:
#             Date          Open          High           Low         Close  \
# 2825  2022-09-26  18803.900391  19274.873047  18721.285156  19222.671875
# 2826  2022-09-27  19221.839844  20338.455078  18915.667969  19110.546875
# 2827  2022-09-28  19104.621094  19688.343750  18553.296875  19426.720703
# 2828  2022-09-29  19427.779297  19589.265625  18924.353516  19573.050781
# 2829  2022-09-30  19573.431641  20109.849609  19265.662109  19431.789063
# 2830  2022-10-01  19431.105469  19471.154297  19231.082031  19312.095703
#
#          Adj Close       Volume
# 2825  19222.671875  44148798321
# 2826  19110.546875  58571439619
# 2827  19426.720703  53071298734
# 2828  19573.050781  41037843771
# 2829  19431.789063  43975248085
# 2830  19312.095703  18719537670

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2831 entries, 0 to 2830
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2831 non-null   object
#  1   Open       2831 non-null   float64
#  2   High       2831 non-null   float64
#  3   Low        2831 non-null   float64
#  4   Close      2831 non-null   float64
#  5   Adj Close  2831 non-null   float64
#  6   Volume     2831 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 154.9+ KB

# %%
df['Close'].max()
# Out:
# 67566.828125

# %%
df['Close'].min()
# Out:
# 178.102997

# %%
df['Close'].mean()
# Out:
# 13163.125503764748

# %%
df.describe()
# Out:
#                Open          High           Low         Close     Adj Close  \
# count   2831.000000   2831.000000   2831.000000   2831.000000   2831.000000
# mean   13158.028722  13497.079532  12778.986850  13163.125504  13163.125504
# std    16537.130807  16962.561024  16044.256896  16532.097862  16532.097862
# min      176.897003    211.731003    171.509995    178.102997    178.102997
# 25%      772.330505    777.540985    765.134002    773.333008    773.333008
# 50%     7153.663086   7320.230469   6936.706543   7152.301758   7152.301758
# 75%    15572.805176  16214.057129  14855.014649  15650.270019  15650.270019
# max    67549.734375  68789.625000  66382.062500  67566.828125  67566.828125
#
#              Volume
# count  2.831000e+03
# mean   1.652474e+10
# std    2.001246e+10
# min    7.860650e+06
# 25%    1.332780e+08
# 50%    7.578786e+09
# 75%    2.822578e+10
# max    3.509679e+11

# %%
df.plot()  #kind = 'scatter' // 'hist'  #x = 'Duration', y = 'Calories'

# %%
df['Close'].plot()

# %%
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')
df['Close'].plot(figsize=(15,3))

# %% [markdown]
# **Questões para um Cientista de Dados**
# * Porque o BTC subiu tanto durante a pandemia?
# * Porque caiu tanto após o fim das restrições?

# %%
df['Close']['01-01-2020':'01-01-2022'].plot(figsize=(15,5))

# %%
## Necessidade do Candlestick
df[['Close', 'Open', 'High', 'Low']]['01-01-2020':'01-01-2022'].plot(figsize=(15,5))

# %%
df[['Volume']]['01-01-2020':'01-01-2022'].plot(figsize=(15,5))

# %% [markdown]
# **Gráfico de Candlestick**
#
# ![tt17_12_12_f1-candlestick-chart-basics-orig-1980983132.jpg](data:image/jpeg;base64,...)

# %%
#Data Cleaning
#df.dropna(axis=0,inplace=True) #We can use the dropna() function to remove the NaNs. axis=0 means that we want to remove all rows that have a NaN value
#df.fillna(130, inplace = True)

# %% [markdown]
# # Indicadores Técnicos
# * Cálculos matemáticos capazes de mostrar tendências, volatilidade, risco, sobrecompra, sobrevenda, etc.
#  * RSI, Bollinger Bands, MACD, etc
#  * Médias Móveis
#    * Estratégia de Investimento: cruzamento de médias móveis (indicador de tendência)
#    * https://br.tradingview.com/

# %%
# Médias Móveis
# Estratégia de negociação:
## Tendência de alta e baixa, de acordo com o cruzamento das médias móveis
df['MA10'] = df['Close'].rolling(10).mean()
#MA 20 CLOSE
df['MA50'] = df['Close'].rolling(50).mean()
#MA 30 CLOSE
df['MA100'] = df['Close'].rolling(100).mean()

df['MA10'].plot()

# %%
df[["Close",'MA10', 'MA50', 'MA100']].plot(figsize = (15,5))

# %%
df[["Close",'MA10', 'MA50', 'MA100']]['01-01-2020':'01-01-2021'].plot(figsize = (15,5))

# %%
df[["Close",'MA10']]['01-01-2020':'01-01-2021'].plot(figsize = (15,5))

# %%
## Cruzamento das médias móveis
df[["Close",'MA10', 'MA50']]['01-01-2020':'01-01-2021'].plot(figsize = (15,5))

# %% [markdown]
# #Correlation measures the relationship between two variables.
# * Values Between -1 and 1
#  * 1 = there is a perfect linear relationship between the variables
#  * 0 = there is no linear relationship between the variables
#  * -1 = there is a perfect negative linear relationship between the variables
#
# **There is an important difference between correlation and causality:**
# * Correlation is a number that measures how closely the data are related
# * Causality is the conclusion that x causes y.
#
# **Correlation Does Not Imply Causality**
#
# * During the summer, the sale of ice cream at a beach increases
# * Simultaneously, drowning accidents also increase as well
# * Does this mean that increase of ice cream sale is a direct cause of increased drowning accidents?

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume  \
# Open       1.000000  0.999512  0.999089  0.998771   0.998771  0.717887
# High       0.999512  1.000000  0.999014  0.999457   0.999457  0.721803
# Low        0.999089  0.999014  1.000000  0.999367   0.999367  0.709621
# Close      0.998771  0.999457  0.999367  1.000000   1.000000  0.716573
# Adj Close  0.998771  0.999457  0.999367  1.000000   1.000000  0.716573
# Volume     0.717887  0.721803  0.709621  0.716573   0.716573  1.000000
# MA10       0.997469  0.997287  0.996389  0.996462   0.996462  0.717693
# MA50       0.978363  0.977967  0.977091  0.976831   0.976831  0.688133
# MA100      0.946647  0.945796  0.945826  0.944887   0.944887  0.642372
#
#                MA10      MA50     MA100
# Open       0.997469  0.978363  0.946647
# High       0.997287  0.977967  0.945796
# Low        0.996389  0.977091  0.945826
# Close      0.996462  0.976831  0.944887
# Adj Close  0.996462  0.976831  0.944887
# Volume     0.717693  0.688133  0.642372
# MA10       1.000000  0.984739  0.954293
# MA50       0.984739  1.000000  0.985655
# MA100      0.954293  0.985655  1.000000

# %%
#HeatMap -- We can use a Heatmap to Visualize the Correlation Between Variables:
import matplotlib.pyplot as plt
import seaborn as sns

correlation_df = df.corr()

axis_corr = sns.heatmap(
correlation_df,
vmin=-1, vmax=1, center=0,
cmap=sns.diverging_palette(50, 500, n=500),
square=True
)

plt.show()

# %% [markdown]
# **Estudos de Correlação**<br>
# - Muito comuns na literatura acadêmica<BR>
# - Precisam ser muito cuidadosos com as variáveis que estão relacionando.
# - Todos se relacionam com a Ciência de Dados.
# - Exemplos
#
#  *   Carne e (ausência ou presença) de doenças
#  *   Lockdown (e outras medidas restritivas) e seus efeitos na transmissão da Covid-19
#  * CO2 e aquecimento global
#  * Eleições
#  * Notícias e mercado
#     * https://scholar.google.com/scholar?hl=pt-BR&as_sdt=0%2C5&q=carosia+stock+market&btnG=
